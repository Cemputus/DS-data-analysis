# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('online_course_engagement_data.csv')
df
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618         Health          29.979719                     17
# 1       4326           Arts          27.802640                      1
# 2       5849           Arts          86.820485                     14
# 3       4992        Science          35.038427                     17
# 4       3866    Programming          92.490647                     16
# ...      ...            ...                ...                    ...
# 8995    8757         Health          37.445225                     14
# 8996     894        Science          48.631443                      7
# 8997    6323         Health          38.212512                      3
# 8998    3652         Health          70.048665                     13
# 8999    5595         Health          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# ...

# %%
df.shape
# Out:
# (9000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UserID                 9000 non-null   int64
#  1   CourseCategory         9000 non-null   object
#  2   TimeSpentOnCourse      9000 non-null   float64
#  3   NumberOfVideosWatched  9000 non-null   int64
#  4   NumberOfQuizzesTaken   9000 non-null   int64
#  5   QuizScores             9000 non-null   float64
#  6   CompletionRate         9000 non-null   float64
#  7   DeviceType             9000 non-null   int64
#  8   CourseCompletion       9000 non-null   int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 632.9+ KB

# %%
df.describe(include='all')
# Out:
#              UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# count   9000.000000           9000        9000.000000            9000.000000
# unique          NaN              5                NaN                    NaN
# top             NaN       Business                NaN                    NaN
# freq            NaN           1837                NaN                    NaN
# mean    4498.894556            NaN          50.163822              10.024667
# std     2596.849433            NaN          28.491750               6.029878
# min        1.000000            NaN           1.005230               0.000000
# 25%     2251.750000            NaN          25.440548               5.000000
# 50%     4483.500000            NaN          49.818417              10.000000
# 75%     6751.250000            NaN          75.069924              15.000000
# max     9000.000000            NaN          99.992558              20.000000
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(877)

# %%
df.drop_duplicates()
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618         Health          29.979719                     17
# 1       4326           Arts          27.802640                      1
# 2       5849           Arts          86.820485                     14
# 3       4992        Science          35.038427                     17
# 4       3866    Programming          92.490647                     16
# ...      ...            ...                ...                    ...
# 8995    8757         Health          37.445225                     14
# 8996     894        Science          48.631443                      7
# 8997    6323         Health          38.212512                      3
# 8998    3652         Health          70.048665                     13
# 8999    5595         Health          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# ...

# %%
df.shape
# Out:
# (9000, 9)

# %%
df.columns
# Out:
# Index(['UserID', 'CourseCategory', 'TimeSpentOnCourse',
#        'NumberOfVideosWatched', 'NumberOfQuizzesTaken', 'QuizScores',
#        'CompletionRate', 'DeviceType', 'CourseCompletion'],
#       dtype='object')

# %%
df.DeviceType.value_counts()
# Out:
# DeviceType
# 1    4506
# 0    4494
# Name: count, dtype: int64

# %%
device_df = df.groupby(['DeviceType','CourseCompletion'])['DeviceType'].agg({'count'})
device_df
# Out:
#                              count
# DeviceType CourseCompletion
# 0          0                  2729
#            1                  1765
# 1          0                  2703
#            1                  1803

# %%
completion_df = df.groupby(['DeviceType'])['CompletionRate'].agg({'mean'})
completion_df
# Out:
#                  mean
# DeviceType
# 0           50.478325
# 1           50.202335

# %%
## Checking for missing values
df.isna().sum()
# Out:
# UserID                   0
# CourseCategory           0
# TimeSpentOnCourse        0
# NumberOfVideosWatched    0
# NumberOfQuizzesTaken     0
# QuizScores               0
# CompletionRate           0
# DeviceType               0
# CourseCompletion         0
# dtype: int64

# %%
cont_df = df.select_dtypes(exclude='object')
cont_df
# Out:
#       UserID  TimeSpentOnCourse  NumberOfVideosWatched  NumberOfQuizzesTaken  \
# 0       5618          29.979719                     17                     3
# 1       4326          27.802640                      1                     5
# 2       5849          86.820485                     14                     2
# 3       4992          35.038427                     17                    10
# 4       3866          92.490647                     16                     0
# ...      ...                ...                    ...                   ...
# 8995    8757          37.445225                     14                     4
# 8996     894          48.631443                      7                     7
# 8997    6323          38.212512                      3                     3
# 8998    3652          70.048665                     13                    10
# 8999    5595          93.589781                      7                     5
#
# ...

# %%
### PLot if it had some missing values
def plot_histplot(df):
    plt.figure(figsize=(20,20))
    for i,col in enumerate(df.columns):
        plt.subplot(3,3,i+1)
        plt.hist(df[col])
        plt.title(col)
    plt.tight_layout()
    plt.show()

# %%
plot_histplot(cont_df)

# %%
def plot_scattertplot(df):
    plt.figure(figsize=(20,20))
    for i,col in enumerate(df.columns):
        plt.subplot(3,3,i+1)
        sns.scatterplot(df[col])
        plt.title(col)
    plt.tight_layout()
    plt.show()

# %%
plot_scattertplot(cont_df)

# %%
### cheching for outliers
def plot_boxtplot(df):
    plt.figure(figsize=(20,20))
    for i,col in enumerate(df.columns):
        plt.subplot(3,3,i+1)
        plt.boxplot(df[col])
        plt.title(col)
    plt.tight_layout()
    plt.show()

# %%
plot_boxtplot(cont_df)

# %%
### Choosing a target
